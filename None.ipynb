# %%
# Question 1: Create a variable and assign None to it
print("Question 1: Create a variable and assign None to it")
a=None
a
# Out:
# Question 1: Create a variable and assign None to it

# %%
# Question 2: Check if None equals None
print("\nQuestion 2: Check if None equals None")
if None==None:
    print("None equals None")
# Out:
# Question 2: Check if None equals None
# None equals None

# %%
# Question 3: Check if None is None
print("\nQuestion 3: Check if None is None")
if None is None:
    print("None is None")
# Out:
# Question 3: Check if None is None
# None is None

# %%
# Question 4: Check if 0 is None
print("\nQuestion 4: Check if 0 is None")
0 is None
# Out:
# Question 4: Check if 0 is None
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipython-input-239505700.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   0 is None
# False

# %%
# Question 5: Check if empty string is None
print("\nQuestion 5: Check if empty string is None")
'' is None
# Out:
# Question 5: Check if empty string is None
# <>:3: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipython-input-1239816410.py:3: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   '' is None
# False

# %%
# Question 6: Check if False is None
print("\nQuestion 6: Check if False is None")
False is None
# Out:
# Question 6: Check if False is None
# False

# %%
# Question 7: Check if empty list is None
print("\nQuestion 7: Check if empty list is None")
[] is None
{} is None
() is None
# Out:
# Question 7: Check if empty list is None
# <>:5: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:5: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# /tmp/ipython-input-4160034790.py:5: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   () is None
# False

# %%
() is None
# Out:
# <>:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# /tmp/ipython-input-1422125243.py:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   () is None
# False

# %%
{} is None
# Out:
# False
